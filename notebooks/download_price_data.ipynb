# %% [markdown]
# # Downlaod the price data and change rates from Yahoo

# %%
from pandas_datareader import data as pdr
import yfinance as yfin

yfin.pdr_override() 

start = '1950-01-01'

# %%
def download_price_data(ticker_list_file, start_date, end_date, dest_dir):
    with open(ticker_list_file, 'r') as f:
        tickers = f.readlines()
        # replace space to dash '-'
        tickers = [ticker.replace(' ', '-').strip() for ticker in tickers]

    for ticker in tickers:
        data = pdr.get_data_yahoo(ticker, start=start_date, end=end_date, timeout=60)
        data.to_csv(f'{dest_dir}/{ticker}.csv')

# %%
download_price_data('../data/ssec.txt', start, None, '../data/prices')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# read in data/sp_500.txt and print out the first 10 lines
download_price_data('../data/sp_500.txt', start, None, '../data/prices')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # read in data/sp_500.txt and print out the first 10 lines
# ----> 2 download_price_data('data/sp_500.txt', start, None, 'data/prices')
#
# Cell In[11], line 2, in download_price_data(ticker_list_file, start_date, end_date, dest_dir)
#       1 def download_price_data(ticker_list_file, start_date, end_date, dest_dir):
# ----> 2     with open(ticker_list_file, 'r') as f:
#       3         tickers = f.readlines()
#       4         # replace space to dash '-'
#
# File /opt/anaconda3/envs/stock/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
# ...

# %%
download_price_data('data/dax_40.txt', start, None, 'data/prices')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
download_price_data('data/omx_30.txt', start, None, 'data/prices')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
download_price_data('data/ftse_100.txt', start, None, 'data/prices')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %% [markdown]
# # Let's find out the exchange rate between below currencies:
#
#
#
#       SEK        GBP         EUO        USD
# SEK    1
# GBP   GBPSEK=X    1
# EUO   EURSEK=X   EURGBP=X      1
# USD   SEK=X      GBP=X        EUR=X             1

# %% [markdown]
# ### we must download below exchange rates: GBPSEK=X EURSEK=X  EURGBP=X SEK=X GBP=X EUR=X

# %%
download_price_data('data/exchange_rates.txt', start, None, 'data/exchange_rates')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
fred_metrics = ['M2SL', 'UNRATE', 'FEDFUNDS', 'DEXUSUK', 'DEXSDUS', 'DEXUSEU']
start='1950-01-01'
for fred in fred_metrics:
  df = pdr.get_data_fred(fred, start=start)
  df.to_csv(f'data/fred/{fred}.csv')
